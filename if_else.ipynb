# %% [markdown]
# Write a program to check if a number is positive, negative, or zero.

# %%
num = 5

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Positive

# %% [markdown]
# Write a program to Check if a number is even or odd

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 3
# Odd

# %% [markdown]
# Write a program to  Check voting eligibility (18+)

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter age: 23
# Eligible to vote

# %% [markdown]
# Write a program to Find the largest of two numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Largest =", a)
else:
    print("Largest =", b)
# Out:
# Enter first number: 12
# Enter second number: 45
# Largest = 45

# %% [markdown]
# Write a program to check if a year is a leap year

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year: 2024
# Leap year

# %% [markdown]
# Write a program to check  Largest of three numbers

# %%
a = int(input("Enter A: "))
b = int(input("Enter B: "))
c = int(input("Enter C: "))

if a >= b and a >= c:
    print("Largest =", a)
elif b >= a and b >= c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter A: 23
# Enter B: 56
# Enter C: 90
# Largest = 90

# %% [markdown]
# Write a program to Check vowel or consonant

# %%
ch = input("Enter a letter: ").lower()

if ch in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a letter: h
# Consonant

# %% [markdown]
# Write a program to Check if a person is a child, teenager, or adult

# %%
age = int(input("Enter age: "))

if age < 13:
    print("Child")
elif age < 18:
    print("Teenager")
else:
    print("Adult")
# Out:
# Enter age: 35
# Adult

# %% [markdown]
# Write a program to Check if a number is a 3-digit number

# %%
num = int(input("Enter a number: "))

if 100 <= num <= 999:
    print("3-digit number")
else:
    print("Not a 3-digit number")
# Out:
# Enter a number: 12
# Not a 3-digit number

# %% [markdown]
# Simple calculator (+, -, , /)

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
op = input("Enter operator (+ - * /): ")

if op == '+':
    print("Result =", a + b)
elif op == '-':
    print("Result =", a - b)
elif op == '*':
    print("Result =", a * b)
elif op == '/':
    print("Result =", a / b)
else:
    print("Invalid operator")
# Out:
# Enter first number: 1
# Enter second number: 23
# Enter operator (+ - * /): /
# Result = 0.043478260869565216

# %% [markdown]
# Write to Check if a triangle is valid

# %%
a = int(input("Side A: "))
b = int(input("Side B: "))
c = int(input("Side C: "))

if a + b > c and a + c > b and b + c > a:
    print("Valid triangle")
else:
    print("Invalid triangle")
# Out:
# Side A: 12
# Side B: 45
# Side C: 67
# Invalid triangle
